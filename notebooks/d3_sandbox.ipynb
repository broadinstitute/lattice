# %% [markdown]
# #### This next cell is here for development purposes. While changes are being made, using this line allows us to reimport

# %%
# to reload modules whenever changes are made
import importlib
importlib.reload(lattice)
# Out:
# You now have access to the lattice.js library python wrapper!
# <module 'py_modules.viz_loader' from '/Users/dnguyen/Projects/pattern-viz/notebooks/py_modules/viz_loader.py'>

# %% [markdown]
# ### First, we need import the Python module that has defined Python methods we can use to interact with the lattice.js library in the notebook.
# In this same cell, we've also imported any IPython display tools needed to run code that isn't recognized by default in the Jupyter Notebook.

# %%
from IPython.display import Javascript, HTML
import py_modules.viz_loader as lattice

# %% [markdown]
# ### Then, we import the lattice.js Javascript wrapper.
# This Javascript file contains functions that are interact with the Python module imported above. This wrapper will take the arguments passed from the user (through the notebook + Python function), do any pre-processing needed, and then calls on the appropriate lattice library function

# %%
Javascript(filename="py_modules/lattice_py.js")
# Javascript(filename="./../src/py_modules/lattice_py.js", css="lattice/build/css/test.css")

# %% [markdown]
# ### Last step before we use the lattice library is to import the CSS.

# %%
# import lattice CSS
HTML(filename="./lattice/build/css/lattice.min.css.html")
# Out:
# <style>
# .ljs--mouseover{stroke-width:1;stroke:#6a6a6a}.x-axis text,.y-axis text{font-size:.55rem;font-weight:300;color:grey}.x-axis>.tick line,.x-axis path,.y-axis>.tick line,.y-axis path{stroke-width:.5px;stroke:#b2b2b2}.ljs--tooltip{display:none;position:absolute;z-index:4000;min-width:50px;padding:8px;text-align:left;background-color:hsla(0,0%,100%,.95);line-height:1.5;font-size:.75rem}.ljs--areaplot-path{fill:#b2b2b2;stroke:#b2b2b2;fill-opacity:.5;stroke-width:.75;stroke-linejoin:round;stroke-linecap:round}.ljs--barcode-line{stroke:#b2b2b2;stroke-width:.1rem}.ljs--lineplot-path{fill:none;stroke:#b2b2b2;stroke-width:1;stroke-linejoin:round;stroke-linecap:round}
# .x-axis text,.y-axis text {
#     font-size: 12px;
# }
# .ljs--tooltip{
#     font-size: 12px;
# }
# </style>

# %%
data = [
    { "x": 0, "y": 0, "c": "steelblue" },
    { "x": 10, "y": 10, "c": "#AAAAAA" },
    { "x": 18, "y": 18, "c": "steelblue" },
    { "x": 20, "y": 45, "c": "#AAAAAA" }
]

# %%
plot_type = "columnplot"
config = {
    "width": 600,
    "height": 200
}
lattice.draw_plot(data, plot_type, config)

# %%
plot_type = "barplot"
config = {
    "width": 200,
    "height": 600
}
lattice.draw_plot(data, plot_type)

# %%
plot_type = "scatterplot"
lattice.draw_plot(data, plot_type)

# %%
lattice_data = [
    {
        "row": 0, "column": 0,
        "data": data,
        "type": "barplot"
    }, {
        "row": 0, "column": 1,
        "data": data,
        "type": "columnplot"
    }
]
lattice.draw_lattice(lattice_data)

# %%
plot_type = "stackedcolumnplot"
config = {
    "xAxis": { "display": False },
    "series": [
        {
          "column": "MutsigCateg_*CpG->T",
          "name": "*CpG->T",
          "color": "#C72C43"
        },
        {
          "column": "MutsigCateg_*CpG->(G/A)",
          "name": "*CpG->(G/A)",
          "color": "#F67F55"
        },
        {
          "column": "MutsigCateg_*Cp(A/C/T)->mut",
          "name": "*Cp(A/C/T)->mut",
          "color": "#FCD97F"
        },
        {
          "column": "MutsigCateg_A->G",
          "name": "A->G",
          "color": "#E2F590"
        },
        {
          "column": "MutsigCateg_A->(T/C)",
          "name": "A->(T/C)",
          "color": "#8BCD84"
        }
  ]
}
data = [
    {
      "series": "*CpG->T",
      "x": "TCGA-OR-A5